# %% [markdown]
# <a href="https://colab.research.google.com/github/Antoine-LR/SQL/blob/main/SQL_to_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import librairies

import pandas as pd
import sqlite3

# %%
#create db connection

cnn = sqlite3.connect("world_cup.db")

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///world_cup.db

# %%
#create a variable to store the url

w_cup_url="https://en.wikipedia.org/wiki/List_of_FIFA_World_Cup_finals"

#create a variable to store list of dataframes in website

w_cup_df = pd.read_html(w_cup_url)

#create variable to store countries url

countries_url = 'https://en.wikipedia.org/wiki/List_of_countries_by_population_(United_Nations)'

#create a variable to store list of dataframes in countries site

countries_df = pd.read_html(countries_url)

# %%
w_cup_df
# Out:
# [                                                   0  \
#  0  France celebrating after their win against Cro...
#  1                                            Founded
#  2                                  Current champions
#  3                            Most successful team(s)
#
#                                                     1
#  0  France celebrating after their win against Cro...
#  1                                 1930; 92 years ago
#  2                                 France (2nd title)
#  3                                  Brazil (5 titles)  ,
#                                                     0  \
#  0  .mw-parser-output .locmap .od{position:absolut...
#
#                                                     1
#  0  Montevideo (1930)Buenos Aires(1978)Rio de Jane...  ,
#          0                                     1
#  0  a.e.t.       Match was won during extra time
#  1    pen.  Match was won on a penalty shoot-out,
# ...

# %%
w_cup_df[3].head(5)
# Out:
#    Year       Winners      Score[2]      Runners-up  \
# 0  1930       Uruguay           4–2       Argentina
# 1  1934         Italy  2–1 (a.e.t.)  Czechoslovakia
# 2  1938         Italy           4–2         Hungary
# 3  1950       Uruguay      2–1[n 3]          Brazil
# 4  1954  West Germany           3–2         Hungary
#
#                          Venue                  Location Attendance      Refs
# 0           Estadio Centenario       Montevideo, Uruguay      80000    [7][8]
# 1         Stadio Nazionale PNF               Rome, Italy      50000   [9][10]
# 2  Stade Olympique de Colombes  Colombes (Paris), France      45000  [11][12]
# 3             Maracanã Stadium    Rio de Janeiro, Brazil     173850  [13][14]
# 4             Wankdorf Stadium         Bern, Switzerland      60000  [15][16]

# %%
w_cup_df[3].columns
# Out:
# Index(['Year', 'Winners', 'Score[2]', 'Runners-up', 'Venue', 'Location',
#        'Attendance', 'Refs'],
#       dtype='object')

# %%
w_cup_df= w_cup_df[3][['Year','Winners','Runners-up']]

# %%
w_cup_df
# Out:
#                Year          Winners       Runners-up
# 0              1930          Uruguay        Argentina
# 1              1934            Italy   Czechoslovakia
# 2              1938            Italy          Hungary
# 3              1950          Uruguay           Brazil
# 4              1954     West Germany          Hungary
# 5              1958           Brazil           Sweden
# 6              1962           Brazil   Czechoslovakia
# 7              1966          England     West Germany
# 8              1970           Brazil            Italy
# 9              1974     West Germany      Netherlands
# 10             1978        Argentina      Netherlands
# 11             1982            Italy     West Germany
# 12             1986        Argentina     West Germany
# 13             1990     West Germany        Argentina
# 14             1994           Brazil            Italy
# 15             1998           France           Brazil
# ...

# %%
# Drop rows with invalid data

w_cup_df= w_cup_df.loc[:20]

# %%
countries_df
# Out:
# [                          Country/Area UN continentalregion[4]  \
#  0                             China[a]                    Asia
#  1                                India                    Asia
#  2                        United States                Americas
#  3                            Indonesia                    Asia
#  4                             Pakistan                    Asia
#  ..                                 ...                     ...
#  229  Falkland Islands (United Kingdom)                Americas
#  230                 Niue (New Zealand)                 Oceania
#  231              Tokelau (New Zealand)                 Oceania
#  232                    Vatican City[z]                  Europe
#  233                              World                     NaN
#
#      UN statisticalsubregion[4]  Population(1 July 2018)  \
#  0                 Eastern Asia               1427647786
#  1                Southern Asia               1352642280
# ...

# %%
# review countries dataframe

countries_df = countries_df[0].iloc[:,[0,1]]

# %%
countries_df = countries_df.drop([233], axis=0)

# %%
countries_df.columns
# Out:
# Index(['Country/Area', 'UN continentalregion[4]'], dtype='object')

# %%
countries_df.columns = ['country', 'region']

# %%
countries_df.head()
# Out:
#          country    region
# 0       China[a]      Asia
# 1          India      Asia
# 2  United States  Americas
# 3      Indonesia      Asia
# 4       Pakistan      Asia

# %%
# write world cup table to database


w_cup_df.to_sql('world_cup2',cnn)

# %%
# %%sql
#
# select * from world_cup2
# Out:
#  * sqlite:///world_cup.db
# Done.
# [(0, '1930', 'Uruguay', 'Argentina'),
#  (1, '1934', 'Italy', 'Czechoslovakia'),
#  (2, '1938', 'Italy', 'Hungary'),
#  (3, '1950', 'Uruguay', 'Brazil'),
#  (4, '1954', 'West Germany', 'Hungary'),
#  (5, '1958', 'Brazil', 'Sweden'),
#  (6, '1962', 'Brazil', 'Czechoslovakia'),
#  (7, '1966', 'England', 'West Germany'),
#  (8, '1970', 'Brazil', 'Italy'),
#  (9, '1974', 'West Germany', 'Netherlands'),
#  (10, '1978', 'Argentina', 'Netherlands'),
#  (11, '1982', 'Italy', 'West Germany'),
#  (12, '1986', 'Argentina', 'West Germany'),
#  (13, '1990', 'West Germany', 'Argentina'),
#  (14, '1994', 'Brazil', 'Italy'),
#  (15, '1998', 'France', 'Brazil'),
#  (16, '2002', 'Brazil', 'Germany'),
#  (17, '2006', 'Italy', 'France'),
#  (18, '2010', 'Spain', 'Netherlands'),
#  (19, '2014', 'Germany', 'Argentina'),
#  (20, '2018', 'France', 'Croatia')]

# %%
# Single table Queries

# %%
# %%sql
#
# select * from world_cup2
# Out:
#  * sqlite:///world_cup.db
# Done.
# [(0, '1930', 'Uruguay', 'Argentina'),
#  (1, '1934', 'Italy', 'Czechoslovakia'),
#  (2, '1938', 'Italy', 'Hungary'),
#  (3, '1950', 'Uruguay', 'Brazil'),
#  (4, '1954', 'West Germany', 'Hungary'),
#  (5, '1958', 'Brazil', 'Sweden'),
#  (6, '1962', 'Brazil', 'Czechoslovakia'),
#  (7, '1966', 'England', 'West Germany'),
#  (8, '1970', 'Brazil', 'Italy'),
#  (9, '1974', 'West Germany', 'Netherlands'),
#  (10, '1978', 'Argentina', 'Netherlands'),
#  (11, '1982', 'Italy', 'West Germany'),
#  (12, '1986', 'Argentina', 'West Germany'),
#  (13, '1990', 'West Germany', 'Argentina'),
#  (14, '1994', 'Brazil', 'Italy'),
#  (15, '1998', 'France', 'Brazil'),
#  (16, '2002', 'Brazil', 'Germany'),
#  (17, '2006', 'Italy', 'France'),
#  (18, '2010', 'Spain', 'Netherlands'),
#  (19, '2014', 'Germany', 'Argentina'),
#  (20, '2018', 'France', 'Croatia')]

# %%
w_cup_df
# Out:
#     Year       Winners      Runners-up
# 0   1930       Uruguay       Argentina
# 1   1934         Italy  Czechoslovakia
# 2   1938         Italy         Hungary
# 3   1950       Uruguay          Brazil
# 4   1954  West Germany         Hungary
# 5   1958        Brazil          Sweden
# 6   1962        Brazil  Czechoslovakia
# 7   1966       England    West Germany
# 8   1970        Brazil           Italy
# 9   1974  West Germany     Netherlands
# 10  1978     Argentina     Netherlands
# 11  1982         Italy    West Germany
# 12  1986     Argentina    West Germany
# 13  1990  West Germany       Argentina
# 14  1994        Brazil           Italy
# 15  1998        France          Brazil
# 16  2002        Brazil         Germany
# 17  2006         Italy          France
# 18  2010         Spain     Netherlands
# 19  2014       Germany       Argentina
# 20  2018        France         Croatia

# %%
# select certain columns in a table

# %%
# %%sql
#
# select winners, year
# from world_cup2
# Out:
#  * sqlite:///world_cup.db
# Done.
# [('Uruguay', '1930'),
#  ('Italy', '1934'),
#  ('Italy', '1938'),
#  ('Uruguay', '1950'),
#  ('West Germany', '1954'),
#  ('Brazil', '1958'),
#  ('Brazil', '1962'),
#  ('England', '1966'),
#  ('Brazil', '1970'),
#  ('West Germany', '1974'),
#  ('Argentina', '1978'),
#  ('Italy', '1982'),
#  ('Argentina', '1986'),
#  ('West Germany', '1990'),
#  ('Brazil', '1994'),
#  ('France', '1998'),
#  ('Brazil', '2002'),
#  ('Italy', '2006'),
#  ('Spain', '2010'),
#  ('Germany', '2014'),
#  ('France', '2018')]

# %%
w_cup_df[['Winners','Year']]
# Out:
#          Winners  Year
# 0        Uruguay  1930
# 1          Italy  1934
# 2          Italy  1938
# 3        Uruguay  1950
# 4   West Germany  1954
# 5         Brazil  1958
# 6         Brazil  1962
# 7        England  1966
# 8         Brazil  1970
# 9   West Germany  1974
# 10     Argentina  1978
# 11         Italy  1982
# 12     Argentina  1986
# 13  West Germany  1990
# 14        Brazil  1994
# 15        France  1998
# 16        Brazil  2002
# 17         Italy  2006
# 18         Spain  2010
# 19       Germany  2014
# 20        France  2018

# %%
w_cup_df.iloc[:,:2]
# Out:
#     Year       Winners
# 0   1930       Uruguay
# 1   1934         Italy
# 2   1938         Italy
# 3   1950       Uruguay
# 4   1954  West Germany
# 5   1958        Brazil
# 6   1962        Brazil
# 7   1966       England
# 8   1970        Brazil
# 9   1974  West Germany
# 10  1978     Argentina
# 11  1982         Italy
# 12  1986     Argentina
# 13  1990  West Germany
# 14  1994        Brazil
# 15  1998        France
# 16  2002        Brazil
# 17  2006         Italy
# 18  2010         Spain
# 19  2014       Germany
# 20  2018        France

# %%
w_cup_df.loc[:,['Winners','Year']]
# Out:
#          Winners  Year
# 0        Uruguay  1930
# 1          Italy  1934
# 2          Italy  1938
# 3        Uruguay  1950
# 4   West Germany  1954
# 5         Brazil  1958
# 6         Brazil  1962
# 7        England  1966
# 8         Brazil  1970
# 9   West Germany  1974
# 10     Argentina  1978
# 11         Italy  1982
# 12     Argentina  1986
# 13  West Germany  1990
# 14        Brazil  1994
# 15        France  1998
# 16        Brazil  2002
# 17         Italy  2006
# 18         Spain  2010
# 19       Germany  2014
# 20        France  2018

# %%
#slect distict rows

# %%
# %%sql
#
# select distinct winners
# from world_cup2
# Out:
#  * sqlite:///world_cup.db
# Done.
# [('Uruguay',),
#  ('Italy',),
#  ('West Germany',),
#  ('Brazil',),
#  ('England',),
#  ('Argentina',),
#  ('France',),
#  ('Spain',),
#  ('Germany',)]

# %%
w_cup_df['Winners'].drop_duplicates()
# Out:
# 0          Uruguay
# 1            Italy
# 4     West Germany
# 5           Brazil
# 7          England
# 10       Argentina
# 15          France
# 18           Spain
# 19         Germany
# Name: Winners, dtype: object

# %%
#sorting columns

# %%
# %%sql
#
# select * from world_cup2
# order by Year desc
# Out:
#  * sqlite:///world_cup.db
# Done.
# [(20, '2018', 'France', 'Croatia'),
#  (19, '2014', 'Germany', 'Argentina'),
#  (18, '2010', 'Spain', 'Netherlands'),
#  (17, '2006', 'Italy', 'France'),
#  (16, '2002', 'Brazil', 'Germany'),
#  (15, '1998', 'France', 'Brazil'),
#  (14, '1994', 'Brazil', 'Italy'),
#  (13, '1990', 'West Germany', 'Argentina'),
#  (12, '1986', 'Argentina', 'West Germany'),
#  (11, '1982', 'Italy', 'West Germany'),
#  (10, '1978', 'Argentina', 'Netherlands'),
#  (9, '1974', 'West Germany', 'Netherlands'),
#  (8, '1970', 'Brazil', 'Italy'),
#  (7, '1966', 'England', 'West Germany'),
#  (6, '1962', 'Brazil', 'Czechoslovakia'),
#  (5, '1958', 'Brazil', 'Sweden'),
#  (4, '1954', 'West Germany', 'Hungary'),
#  (3, '1950', 'Uruguay', 'Brazil'),
#  (2, '1938', 'Italy', 'Hungary'),
#  (1, '1934', 'Italy', 'Czechoslovakia'),
#  (0, '1930', 'Uruguay', 'Argentina')]

# %%
w_cup_df.sort_values(['Year'],ascending=False)
# Out:
#     Year       Winners      Runners-up
# 20  2018        France         Croatia
# 19  2014       Germany       Argentina
# 18  2010         Spain     Netherlands
# 17  2006         Italy          France
# 16  2002        Brazil         Germany
# 15  1998        France          Brazil
# 14  1994        Brazil           Italy
# 13  1990  West Germany       Argentina
# 12  1986     Argentina    West Germany
# 11  1982         Italy    West Germany
# 10  1978     Argentina     Netherlands
# 9   1974  West Germany     Netherlands
# 8   1970        Brazil           Italy
# 7   1966       England    West Germany
# 6   1962        Brazil  Czechoslovakia
# 5   1958        Brazil          Sweden
# 4   1954  West Germany         Hungary
# 3   1950       Uruguay          Brazil
# 2   1938         Italy         Hungary
# 1   1934         Italy  Czechoslovakia
# 0   1930       Uruguay       Argentina

# %%
w_cup_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        21 non-null     object
#  1   Winners     21 non-null     object
#  2   Runners-up  21 non-null     object
# dtypes: object(3)
# memory usage: 632.0+ bytes

# %%
# select First N Elements

# %%
# %%sql
#
# select * from world_cup2
# limit 5
# Out:
#  * sqlite:///world_cup.db
# Done.
# [(0, '1930', 'Uruguay', 'Argentina'),
#  (1, '1934', 'Italy', 'Czechoslovakia'),
#  (2, '1938', 'Italy', 'Hungary'),
#  (3, '1950', 'Uruguay', 'Brazil'),
#  (4, '1954', 'West Germany', 'Hungary')]

# %%
w_cup_df.head()
# Out:
#    Year       Winners      Runners-up
# 0  1930       Uruguay       Argentina
# 1  1934         Italy  Czechoslovakia
# 2  1938         Italy         Hungary
# 3  1950       Uruguay          Brazil
# 4  1954  West Germany         Hungary

# %%
#select Last N elements

# %%
# %%sql
#
# select * from world_cup2
# order by Year desc
# limit 5
# Out:
#  * sqlite:///world_cup.db
# Done.
# [(20, '2018', 'France', 'Croatia'),
#  (19, '2014', 'Germany', 'Argentina'),
#  (18, '2010', 'Spain', 'Netherlands'),
#  (17, '2006', 'Italy', 'France'),
#  (16, '2002', 'Brazil', 'Germany')]

# %%
w_cup_df.sort_values('Year', ascending=False).head(5)
# Out:
#     Year  Winners   Runners-up
# 20  2018   France      Croatia
# 19  2014  Germany    Argentina
# 18  2010    Spain  Netherlands
# 17  2006    Italy       France
# 16  2002   Brazil      Germany

# %%
# Last N with Offset

# %%
# %%sql
#
# select* from world_cup2
# order by Year desc
# limit 5 Offset 1
# Out:
#  * sqlite:///world_cup.db
# Done.
# [(19, '2014', 'Germany', 'Argentina'),
#  (18, '2010', 'Spain', 'Netherlands'),
#  (17, '2006', 'Italy', 'France'),
#  (16, '2002', 'Brazil', 'Germany'),
#  (15, '1998', 'France', 'Brazil')]

# %%
w_cup_df.iloc[-6:-1,:].sort_values(['Year'],ascending=False).head(5)
# Out:
#     Year  Winners   Runners-up
# 19  2014  Germany    Argentina
# 18  2010    Spain  Netherlands
# 17  2006    Italy       France
# 16  2002   Brazil      Germany
# 15  1998   France       Brazil
